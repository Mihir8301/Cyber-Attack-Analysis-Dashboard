# %%
import pandas as pd

# %%
data= pd.read_excel('CrystalPools.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 data= pd.read_excel('CrystalPools.xlsx')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:504, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502 if not isinstance(io, ExcelFile):
#     503     should_close = True
# --> 504     io = ExcelFile(
#     505         io,
#     506         storage_options=storage_options,
#     507         engine=engine,
#     508         engine_kwargs=engine_kwargs,
#     509     )
#     510 elif engine and engine != io.engine:
#     511     raise ValueError(
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13407 entries, 0 to 13406
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   slug                     13407 non-null  object
#  1   event_date               13407 non-null  datetime64[ns]
#  2   event_year               13407 non-null  int64
#  3   affected_country         13407 non-null  object
#  4   affected_organization    13407 non-null  object
#  5   affected_industry        13407 non-null  object
#  6   afftected_industry_code  13407 non-null  int64
#  7   event_type               13407 non-null  object
#  8   event_subtype            13407 non-null  object
#  9   motive                   13407 non-null  object
#  10  description              13407 non-null  object
#  11  actor                    13407 non-null  object
#  12  actor_type               13407 non-null  object
#  13  actor_country            13407 non-null  object
# ...

# %%
data
# Out:
# slug                       0
# event_date                 0
# event_year                 0
# affected_country           0
# affected_organization      0
# affected_industry          0
# afftected_industry_code    0
# event_type                 0
# event_subtype              0
# motive                     0
# description                0
# actor                      0
# actor_type                 0
# actor_country              0
# source_url                 0
# dtype: int64

# %%
data['Sale Price'].isnull().sum()
# Out:
# 0

# %%
data['Profit']= data['Sale Price']- data['Store Cost']
data
# Out:
#     Month  Transaction Number  Product Code Product Description  Store Cost  \
# 0     Jan                1001          9822          Pool Cover        58.3
# 1     Jan                1002          2877                 Net        11.4
# 2     Jan                1003          2499           8 ft Hose         6.2
# 3     Jan                1004          8722          Water Pump       344.0
# 4     Jan                1005          1109   Chlorine Test Kit         3.0
# ..    ...                 ...           ...                 ...         ...
# 166   Dec                1167          2242             AutoVac        60.0
# 167   Dec                1168          9822          Pool Cover        58.3
# 168   Dec                1169          8722          Water Pump       344.0
# 169   Dec                1170          4421             Skimmer        45.0
# 170   Dec                1171          4421             Skimmer        45.0
#
# ...

# %%
data
# Out:
#     Month  Transaction Number  Product Code Product Description  Store Cost  \
# 0     Jan                1001          9822          Pool Cover        58.3
# 1     Jan                1002          2877                 Net        11.4
# 2     Jan                1003          2499           8 ft Hose         6.2
# 3     Jan                1004          8722          Water Pump       344.0
# 4     Jan                1005          1109   Chlorine Test Kit         3.0
# ..    ...                 ...           ...                 ...         ...
# 166   Dec                1167          2242             AutoVac        60.0
# 167   Dec                1168          9822          Pool Cover        58.3
# 168   Dec                1169          8722          Water Pump       344.0
# 169   Dec                1170          4421             Skimmer        45.0
# 170   Dec                1171          4421             Skimmer        45.0
#
# ...

# %%
data1=data.copy()

# %%
data1
# Out:
#     Month  Transaction Number  Product Code Product Description  Store Cost  \
# 0     Jan                1001          9822          Pool Cover        58.3
# 1     Jan                1002          2877                 Net        11.4
# 2     Jan                1003          2499           8 ft Hose         6.2
# 3     Jan                1004          8722          Water Pump       344.0
# 4     Jan                1005          1109   Chlorine Test Kit         3.0
# ..    ...                 ...           ...                 ...         ...
# 166   Dec                1167          2242             AutoVac        60.0
# 167   Dec                1168          9822          Pool Cover        58.3
# 168   Dec                1169          8722          Water Pump       344.0
# 169   Dec                1170          4421             Skimmer        45.0
# 170   Dec                1171          4421             Skimmer        45.0
#
# ...

# %%
com=pd.read_excel('CrystalPools.xlsx')
# Out:
# C:\Users\M J\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
com
# Out:
#     Month  Transaction Number  Product Code Product Description  Store Cost  \
# 0     Jan                1001          9822          Pool Cover        58.3
# 1     Jan                1002          2877                 Net        11.4
# 2     Jan                1003          2499           8 ft Hose         6.2
# 3     Jan                1004          8722          Water Pump       344.0
# 4     Jan                1005          1109   Chlorine Test Kit         3.0
# ..    ...                 ...           ...                 ...         ...
# 166   Dec                1167          2242             AutoVac        60.0
# 167   Dec                1168          9822          Pool Cover        58.3
# 168   Dec                1169          8722          Water Pump       344.0
# 169   Dec                1170          4421             Skimmer        45.0
# 170   Dec                1171          4421             Skimmer        45.0
#
# ...

# %%
com.loc[2,['Sale Price']]= 3.2

# %%
com
# Out:
#     Month  Transaction Number  Product Code Product Description  Store Cost  \
# 0     Jan                1001          9822          Pool Cover        58.3
# 1     Jan                1002          2877                 Net        11.4
# 2     Jan                1003          2499           8 ft Hose         6.2
# 3     Jan                1004          8722          Water Pump       344.0
# 4     Jan                1005          1109   Chlorine Test Kit         3.0
# ..    ...                 ...           ...                 ...         ...
# 166   Dec                1167          2242             AutoVac        60.0
# 167   Dec                1168          9822          Pool Cover        58.3
# 168   Dec                1169          8722          Water Pump       344.0
# 169   Dec                1170          4421             Skimmer        45.0
# 170   Dec                1171          4421             Skimmer        45.0
#
# ...

# %%
com.loc[170,['Sale Price']]= 43

# %%
com
# Out:
#     Month  Transaction Number  Product Code Product Description  Store Cost  \
# 0     Jan                1001          9822          Pool Cover        58.3
# 1     Jan                1002          2877                 Net        11.4
# 2     Jan                1003          2499           8 ft Hose         6.2
# 3     Jan                1004          8722          Water Pump       344.0
# 4     Jan                1005          1109   Chlorine Test Kit         3.0
# ..    ...                 ...           ...                 ...         ...
# 166   Dec                1167          2242             AutoVac        60.0
# 167   Dec                1168          9822          Pool Cover        58.3
# 168   Dec                1169          8722          Water Pump       344.0
# 169   Dec                1170          4421             Skimmer        45.0
# 170   Dec                1171          4421             Skimmer        45.0
#
# ...

# %%
com1=com.copy()

# %%
# Out:
#     Month  Transaction Number  Product Code Product Description  Store Cost  \
# 0     Jan                1001          9822          Pool Cover        58.3
# 1     Jan                1002          2877                 Net        11.4
# 2     Jan                1003          2499           8 ft Hose         6.2
# 3     Jan                1004          8722          Water Pump       344.0
# 4     Jan                1005          1109   Chlorine Test Kit         3.0
# ..    ...                 ...           ...                 ...         ...
# 166   Dec                1167          2242             AutoVac        60.0
# 167   Dec                1168          9822          Pool Cover        58.3
# 168   Dec                1169          8722          Water Pump       344.0
# 169   Dec                1170          4421             Skimmer        45.0
# 170   Dec                1171          4421             Skimmer        45.0
#
# ...

# %%
if sal > 50:
    com1['Profit']= com1['Sale Price']- com1['Store Cost']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [24], line 1
# ----> 1 if sal > 50:
#       2     com1['Profit']= com1['Sale Price']- com1['Store Cost']
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:1526, in NDFrame.__nonzero__(self)
#    1524 @final
#    1525 def __nonzero__(self) -> NoReturn:
# -> 1526     raise ValueError(
#    1527         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1528         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1529     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
sal=com1.loc[:,'Sale Price']
sal
# Out:
# 0       98.4
# 1       16.3
# 2        3.2
# 3      502.0
# 4        8.0
#        ...
# 166    124.0
# 167     98.4
# 168    502.0
# 169     87.0
# 170     43.0
# Name: Sale Price, Length: 171, dtype: float64

# %%
def myfun(num):
    if num > 50:
        com1['Profit']= num - com1['Store Cost']
    else:
        print('None')
    
com1['Profit'].apply(myfun)
com1
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %%
com1
# Out:
#     Month  Transaction Number  Product Code Product Description  Store Cost  \
# 0     Jan                1001          9822          Pool Cover        58.3
# 1     Jan                1002          2877                 Net        11.4
# 2     Jan                1003          2499           8 ft Hose         6.2
# 3     Jan                1004          8722          Water Pump       344.0
# 4     Jan                1005          1109   Chlorine Test Kit         3.0
# ..    ...                 ...           ...                 ...         ...
# 166   Dec                1167          2242             AutoVac        60.0
# 167   Dec                1168          9822          Pool Cover        58.3
# 168   Dec                1169          8722          Water Pump       344.0
# 169   Dec                1170          4421             Skimmer        45.0
# 170   Dec                1171          4421             Skimmer        45.0
#
# ...

# %%
com1.loc[:,['Profit']]=0
# Out:
# C:\Users\M J\AppData\Local\Temp\ipykernel_6768\4284991795.py:1: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   com1.loc[:,['Profit']]=0

# %%
com1
# Out:
#     Month  Transaction Number  Product Code Product Description  Store Cost  \
# 0     Jan                1001          9822          Pool Cover        58.3
# 1     Jan                1002          2877                 Net        11.4
# 2     Jan                1003          2499           8 ft Hose         6.2
# 3     Jan                1004          8722          Water Pump       344.0
# 4     Jan                1005          1109   Chlorine Test Kit         3.0
# ..    ...                 ...           ...                 ...         ...
# 166   Dec                1167          2242             AutoVac        60.0
# 167   Dec                1168          9822          Pool Cover        58.3
# 168   Dec                1169          8722          Water Pump       344.0
# 169   Dec                1170          4421             Skimmer        45.0
# 170   Dec                1171          4421             Skimmer        45.0
#
# ...

# %%
com1
# Out:
#     Month  Transaction Number  Product Code Product Description  Store Cost  \
# 0     Jan                1001          9822          Pool Cover        58.3
# 1     Jan                1002          2877                 Net        11.4
# 2     Jan                1003          2499           8 ft Hose         6.2
# 3     Jan                1004          8722          Water Pump       344.0
# 4     Jan                1005          1109   Chlorine Test Kit         3.0
# ..    ...                 ...           ...                 ...         ...
# 166   Dec                1167          2242             AutoVac        60.0
# 167   Dec                1168          9822          Pool Cover        58.3
# 168   Dec                1169          8722          Water Pump       344.0
# 169   Dec                1170          4421             Skimmer        45.0
# 170   Dec                1171          4421             Skimmer        45.0
#
# ...

# %%
import numpy as np

# %%
com1['Profit']=np.where(com1['Sale Price']>com1['Store Cost'], com1['Sale Price'] - com1['Store Cost'],com1['Store Cost']-com1['Sale Price'])

# %%
com1
# Out:
#     Month  Transaction Number  Product Code Product Description  Store Cost  \
# 0     Jan                1001          9822          Pool Cover        58.3
# 1     Jan                1002          2877                 Net        11.4
# 2     Jan                1003          2499           8 ft Hose         6.2
# 3     Jan                1004          8722          Water Pump       344.0
# 4     Jan                1005          1109   Chlorine Test Kit         3.0
# ..    ...                 ...           ...                 ...         ...
# 166   Dec                1167          2242             AutoVac        60.0
# 167   Dec                1168          9822          Pool Cover        58.3
# 168   Dec                1169          8722          Water Pump       344.0
# 169   Dec                1170          4421             Skimmer        45.0
# 170   Dec                1171          4421             Skimmer        45.0
#
# ...

# %% [raw]
# com1['Commision 10%']=np.where(com1['Sale Price']>50, com1['Profit']*0.2,com1['Profit']*0.1)

# %%
com1
# Out:
#     Month  Transaction Number  Product Code Product Description  Store Cost  \
# 0     Jan                1001          9822          Pool Cover        58.3
# 1     Jan                1002          2877                 Net        11.4
# 2     Jan                1003          2499           8 ft Hose         6.2
# 3     Jan                1004          8722          Water Pump       344.0
# 4     Jan                1005          1109   Chlorine Test Kit         3.0
# ..    ...                 ...           ...                 ...         ...
# 166   Dec                1167          2242             AutoVac        60.0
# 167   Dec                1168          9822          Pool Cover        58.3
# 168   Dec                1169          8722          Water Pump       344.0
# 169   Dec                1170          4421             Skimmer        45.0
# 170   Dec                1171          4421             Skimmer        45.0
#
# ...

# %%
com1['Product Description']=np.where(com1['Product Description']=='Pool','pop','Pool' )

# %%
com1
# Out:
#     Month  Transaction Number  Product Code Product Description  Store Cost  \
# 0     Jan                1001          9822                Pool        58.3
# 1     Jan                1002          2877                Pool        11.4
# 2     Jan                1003          2499                Pool         6.2
# 3     Jan                1004          8722                Pool       344.0
# 4     Jan                1005          1109                Pool         3.0
# ..    ...                 ...           ...                 ...         ...
# 166   Dec                1167          2242                Pool        60.0
# 167   Dec                1168          9822                Pool        58.3
# 168   Dec                1169          8722                Pool       344.0
# 169   Dec                1170          4421                Pool        45.0
# 170   Dec                1171          4421                Pool        45.0
#
# ...

# %%
com2= com.copy()

# %%
def myfun(text):
    if(text=='None'):
        return "Pool Cover"
com2['Product Description']=com2['Product Description'].apply(myfun)

# %%
com2
# Out:
#     Month  Transaction Number  Product Code Product Description  Store Cost  \
# 0     Jan                1001          9822                None        58.3
# 1     Jan                1002          2877                None        11.4
# 2     Jan                1003          2499                None         6.2
# 3     Jan                1004          8722                None       344.0
# 4     Jan                1005          1109                None         3.0
# ..    ...                 ...           ...                 ...         ...
# 166   Dec                1167          2242                None        60.0
# 167   Dec                1168          9822                None        58.3
# 168   Dec                1169          8722                None       344.0
# 169   Dec                1170          4421                None        45.0
# 170   Dec                1171          4421                None        45.0
#
# ...

# %%
com3=com.copy()

# %%
com3
# Out:
#     Month  Transaction Number  Product Code Product Description  Store Cost  \
# 0     Jan                1001          9822          Pool Cover        58.3
# 1     Jan                1002          2877                 Net        11.4
# 2     Jan                1003          2499           8 ft Hose         6.2
# 3     Jan                1004          8722          Water Pump       344.0
# 4     Jan                1005          1109   Chlorine Test Kit         3.0
# ..    ...                 ...           ...                 ...         ...
# 166   Dec                1167          2242             AutoVac        60.0
# 167   Dec                1168          9822          Pool Cover        58.3
# 168   Dec                1169          8722          Water Pump       344.0
# 169   Dec                1170          4421             Skimmer        45.0
# 170   Dec                1171          4421             Skimmer        45.0
#
# ...

# %%
com3['Profit']=com3['Sale Price']-com3['Store Cost']

# %%
com3
# Out:
#     Month  Transaction Number  Product Code Product Description  Store Cost  \
# 0     Jan                1001          9822                pool        58.3
# 1     Jan                1002          2877                None        11.4
# 2     Jan                1003          2499                None         6.2
# 3     Jan                1004          8722                None       344.0
# 4     Jan                1005          1109                None         3.0
# ..    ...                 ...           ...                 ...         ...
# 166   Dec                1167          2242                None        60.0
# 167   Dec                1168          9822                pool        58.3
# 168   Dec                1169          8722                None       344.0
# 169   Dec                1170          4421                None        45.0
# 170   Dec                1171          4421                None        45.0
#
# ...

# %%
def profit_func(num):
    if num > 50:
        return "high"
    else:
        return 'low'

com3['Profit'].apply(profit_func)
# Out:
# 0       low
# 1       low
# 2       low
# 3      high
# 4       low
#        ...
# 166    high
# 167     low
# 168    high
# 169     low
# 170     low
# Name: Profit, Length: 171, dtype: object

# %%
com3
# Out:
#     Month  Transaction Number  Product Code Product Description  Store Cost  \
# 0     Jan                1001          9822                pool        58.3
# 1     Jan                1002          2877                None        11.4
# 2     Jan                1003          2499                None         6.2
# 3     Jan                1004          8722                None       344.0
# 4     Jan                1005          1109                None         3.0
# ..    ...                 ...           ...                 ...         ...
# 166   Dec                1167          2242                None        60.0
# 167   Dec                1168          9822                pool        58.3
# 168   Dec                1169          8722                None       344.0
# 169   Dec                1170          4421                None        45.0
# 170   Dec                1171          4421                None        45.0
#
# ...

# %%
def cap(text):
    return text.capitalize()
    
com3['Profit Ratio']=com3['Profit Ratio'].apply(cap)

# %%
com3
# Out:
#     Month  Transaction Number  Product Code Product Description  Store Cost  \
# 0     Jan                1001          9822                pool        58.3
# 1     Jan                1002          2877                None        11.4
# 2     Jan                1003          2499                None         6.2
# 3     Jan                1004          8722                None       344.0
# 4     Jan                1005          1109                None         3.0
# ..    ...                 ...           ...                 ...         ...
# 166   Dec                1167          2242                None        60.0
# 167   Dec                1168          9822                pool        58.3
# 168   Dec                1169          8722                None       344.0
# 169   Dec                1170          4421                None        45.0
# 170   Dec                1171          4421                None        45.0
#
# ...

# %%
def job(title):
    if title=='None':
        return 'Pool cover'
    else:
        return title

com3['Product Description']=com3['Product Description'].apply(job)

# %%
com3.replace(to_replace='pool',value='Pool Cover')
# Out:
#     Month  Transaction Number  Product Code Product Description  Store Cost  \
# 0     Jan                1001          9822          Pool Cover        58.3
# 1     Jan                1002          2877                None        11.4
# 2     Jan                1003          2499                None         6.2
# 3     Jan                1004          8722                None       344.0
# 4     Jan                1005          1109                None         3.0
# ..    ...                 ...           ...                 ...         ...
# 166   Dec                1167          2242                None        60.0
# 167   Dec                1168          9822          Pool Cover        58.3
# 168   Dec                1169          8722                None       344.0
# 169   Dec                1170          4421                None        45.0
# 170   Dec                1171          4421                None        45.0
#
# ...

# %%
com3
# Out:
#     Month  Transaction Number  Product Code Product Description  Store Cost  \
# 0     Jan                1001          9822                pool        58.3
# 1     Jan                1002          2877                None        11.4
# 2     Jan                1003          2499                None         6.2
# 3     Jan                1004          8722                None       344.0
# 4     Jan                1005          1109                None         3.0
# ..    ...                 ...           ...                 ...         ...
# 166   Dec                1167          2242                None        60.0
# 167   Dec                1168          9822                pool        58.3
# 168   Dec                1169          8722                None       344.0
# 169   Dec                1170          4421                None        45.0
# 170   Dec                1171          4421                None        45.0
#
# ...

# %%
com3[com3['Sale Price']>100][['Sale Price','Profit','Sale Location','Profit Ratio']]
# Out:
#      Sale Price  Profit Sale Location Profit Ratio
# 3         502.0   158.0            AZ         High
# 13        502.0   158.0            CA         High
# 16        124.0    64.0            NM         High
# 27        502.0   158.0            AZ         High
# 41        502.0   158.0            NM         High
# 42        124.0    64.0            CA         High
# 44        502.0   158.0            AZ         High
# 47        502.0   158.0            AZ         High
# 52        124.0    64.0            CA         High
# 58        124.0    64.0            AZ         High
# 101       124.0    64.0            NV         High
# 108       502.0   158.0            CA         High
# 109       502.0   158.0            NV         High
# 113       124.0    64.0            AZ         High
# 114       502.0   158.0            AZ         High
# 116       502.0   158.0            NM         High
# 118       124.0    64.0            UT         High
# ...

# %%
com3.groupby(['Month'])[['Transaction Number']].agg(['count'])
# Out:
#       Transaction Number
#                    count
# Month
# April                 12
# Aug                   17
# Dec                    5
# Feb                   18
# Jan                   16
# July                  26
# June                  20
# Mar                   14
# May                   18
# Nov                    9
# Oct                    8
# Sept                   8

# %%
cp1=com3.groupby(['Month','Sale Location'],as_index=False)[['Profit']].sum()

# %%
cp1
# Out:
#     Month Sale Location  Profit
# 0   April            AZ   108.9
# 1   April            CA    72.0
# 2   April            CO     3.0
# 3   April            NV    52.0
# 4   April            UT     5.0
# 5     Aug            AZ    86.2
# 6     Aug            CA   226.1
# 7     Aug            NM    67.0
# 8     Aug            NV   398.1
# 9     Aug            UT   158.0
# 10    Dec            CA    82.1
# 11    Dec            NM    64.0
# 12    Dec            NV    -2.0
# 13    Dec            UT   158.0
# 14    Feb            AZ   165.9
# 15    Feb            CA    50.1
# 16    Feb            CO    12.9
# 17    Feb            NM    74.0
# 18    Feb            NV    54.9
# 19    Feb            UT     7.9
# 20    Jan            AZ   214.9
# 21    Jan            CA   165.9
# 22    Jan            CO     7.9
# 23    Jan            NM    92.0
# 24   July            AZ   464.9
# 25   July            CA   385.2
# 26   July            NM   163.0
# 27   July            NV   384.1
# ...

# %%
cp2=cp1.groupby(['Month'])[['Profit']].max()
cp2
# Out:
#        Profit
# Month
# April   108.9
# Aug     398.1
# Dec     158.0
# Feb     165.9
# Jan     214.9
# July    464.9
# June     64.8
# Mar     356.0
# May      69.0
# Nov     356.1
# Oct     200.0
# Sept    222.0

# %%
cp2.min()
# Out:
# Profit    64.8
# dtype: float64

# %%
data1
# Out:
#     Month  Transaction Number  Product Code Product Description  Store Cost  \
# 0     Jan                1001          9822          Pool Cover        58.3
# 1     Jan                1002          2877                 Net        11.4
# 2     Jan                1003          2499           8 ft Hose         6.2
# 3     Jan                1004          8722          Water Pump       344.0
# 4     Jan                1005          1109   Chlorine Test Kit         3.0
# ..    ...                 ...           ...                 ...         ...
# 166   Dec                1167          2242             AutoVac        60.0
# 167   Dec                1168          9822          Pool Cover        58.3
# 168   Dec                1169          8722          Water Pump       344.0
# 169   Dec                1170          4421             Skimmer        45.0
# 170   Dec                1171          4421             Skimmer        45.0
#
# ...

# %%
data1.groupby(['Product Code','Product Description'])['Sale Price'].max()
# Out:
# Product Code  Product Description
# 1109          Chlorine Test Kit        8.0
# 2242          AutoVac                124.0
# 2499          8 ft Hose                9.2
# 2877          Net                     16.3
# 4421          Skimmer                 87.0
# 6119          Algea Killer 8 oz       14.0
# 6622          5 Gal Chlorine          77.0
# 8722          Water Pump             502.0
# 9212          1 Gal Muratic Acid       7.0
# 9822          Pool Cover              98.4
# Name: Sale Price, dtype: float64

# %%
data1['Product Description'].value_counts()
# Out:
# Net                   24
# Pool Cover            21
# 8 ft Hose             20
# Water Pump            20
# Chlorine Test Kit     20
# AutoVac               16
# Skimmer               15
# Algea Killer 8 oz     15
# 1 Gal Muratic Acid    11
# 5 Gal Chlorine         9
# Name: Product Description, dtype: int64
