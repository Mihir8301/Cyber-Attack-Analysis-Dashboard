# %%
import pandas as pd

# %%
df=pd.read_csv("nba.csv")

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.isnull().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
df.dropna(how='all',inplace=True)

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df.loc[:,['College']].head(25)
# Out:
#               College
# 0               Texas
# 1           Marquette
# 2   Boston University
# 3       Georgia State
# 4                 NaN
# 5                 NaN
# 6                 LSU
# 7             Gonzaga
# 8          Louisville
# 9      Oklahoma State
# 10         Ohio State
# 11         Washington
# 12         Ohio State
# 13           Kentucky
# 14     North Carolina
# 15                NaN
# 16     Oklahoma State
# 17     North Carolina
# 18            Arizona
# 19       Georgia Tech
# 20                NaN
# 21         Cincinnati
# 22         Miami (FL)
# 23           Stanford
# 24           Syracuse

# %%
df.fillna(value='None')
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df.duplicated(subset='College',keep=False).sum()
# Out:
# 405

# %%
df.fillna(value='None',inplace=True)

# %%
df.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
df1=df[df['Age']>25.0]
df1
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5     Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 11   Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9   185.0
# 12     Evan Turner  Boston Celtics    11.0       SG  27.0    6-7   220.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 450     Joe Ingles       Utah Jazz     2.0       SF  28.0    6-8   226.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College      Salary
# 2    Boston University        None
# ...

# %%
df2=df[(df['Team']=='Boston Celtics') & (df['Weight']>200)]
df2
# Out:
#                Name            Team  Number Position   Age Height  Weight  \
# 1       Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2      John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 4     Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5      Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6     Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7      Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 9      Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 10  Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
# 12      Evan Turner  Boston Celtics    11.0       SG  27.0    6-7   220.0
# 13      James Young  Boston Celtics    13.0       SG  20.0    6-6   215.0
# 14     Tyler Zeller  Boston Celtics    44.0        C  26.0    7-0   253.0
#
#               College      Salary
# 1           Marquette   6796117.0
# ...

# %%
var=df.groupby(['Weight','Team'])

# %%
var.get_group([235,'Boston Celtics'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [42], line 1
# ----> 1 var.get_group([235,'Boston Celtics'])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:809, in BaseGroupBy.get_group(self, name, obj)
#     806 if obj is None:
#     807     obj = self._selected_obj
# --> 809 inds = self._get_index(name)
#     810 if not len(inds):
#     811     raise KeyError(name)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:737, in BaseGroupBy._get_index(self, name)
#     732 @final
#     733 def _get_index(self, name):
#     734     """
#     735     Safe get index, translate keys for datelike to underlying repr.
#     736     """
# --> 737     return self._get_indices([name])[0]
#
# ...

# %%
for x,y in var:
    print(x)
    print(y)
    print()
# Out:
# (161.0, 'Chicago Bulls')
#              Name           Team  Number Position   Age Height  Weight  \
# 152  Aaron Brooks  Chicago Bulls     0.0       PG  31.0    6-0   161.0
#
#     College     Salary
# 152  Oregon  2250000.0
#
# (165.0, 'Memphis Grizzlies')
#              Name               Team  Number Position   Age Height  Weight  \
# 263  Bryce Cotton  Memphis Grizzlies     8.0       PG  23.0    6-1   165.0
#
#         College    Salary
# 263  Providence  700902.0
#
# (165.0, 'Miami Heat')
#               Name        Team  Number Position   Age Height  Weight  \
# 350  Briante Weber  Miami Heat    12.0       PG  23.0    6-2   165.0
#
#                    College Salary
# 350  Virginia Commonwealth   None
#
# (169.0, 'Orlando Magic')
#                  Name           Team  Number Position   Age Height  Weight  \
# 359  Brandon Jennings  Orlando Magic    55.0       PG  26.0    6-1   169.0
#
#     College     Salary
# 359    None  8344497.0
#
# (170.0, 'New Orleans Pelicans')
# ...

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df['college_year']='2nd Year'
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary college_year
# ...

# %%
df.drop('college_year',axis=1,inplace=True)

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df['Age'].max()
# Out:
# 40.0

# %%
df['Age'].min()
# Out:
# 19.0

# %%
def clg(title):
    if title>=19 and title<25:
        return "1st Year"
    elif title>=25 and title<30:
        return "2nd Year"
    elif title>=30 and title<35:
        return "3rd Year"
    else:
        return "4th Year"

# %%
df['college_year']= df["Age"].apply(clg)

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary college_year
# ...

# %%
df.map({
    '2nd':'2st'
})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [63], line 1
# ----> 1 df.map({
#       2     '2nd':'2st'
#       3 })
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5907, in NDFrame.__getattr__(self, name)
#    5900 if (
#    5901     name not in self._internal_names_set
#    5902     and name not in self._metadata
#    5903     and name not in self._accessors
#    5904     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5905 ):
#    5906     return self[name]
# -> 5907 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'map'

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary college_year
# ...

# %%
s = pd.Series(['fox', 'cow', 'dog','cowlf'])
s.map({'fox': 'cub', 'cow': 'calf'})
# Out:
# 0     cub
# 1    calf
# 2     NaN
# dtype: object

# %%
s.replace(to_replace='cow',value='kow')
# Out:
# 0    fox
# 1    kow
# 2    dog
# dtype: object

# %%
df['458']='Jod'

# %%
df.drop('458',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [80], line 1
# ----> 1 df.drop('458',axis=1,inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5391, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5243 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5244 def drop(  # type: ignore[override]
# ...

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary college_year  458
# ...

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary college_year  458
# ...

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary college_year  458
# ...

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary college_year  458
# ...

# %%
df.drop('458',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [83], line 1
# ----> 1 df.drop('458',axis=1)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5391, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5243 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5244 def drop(  # type: ignore[override]
# ...

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary college_year  458
# ...

# %%
df.replace(to_replace='458',value='Col')
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary college_year  458
# ...

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary college_year  458
# ...

# %%
df.isnull().sum()
# Out:
# Name            0
# Team            0
# Number          0
# Position        0
# Age             0
# Height          0
# Weight          0
# College         0
# Salary          0
# college_year    0
# 458             0
# dtype: int64

# %%
df.drop(458,axis=1,inplace=True)

# %%
df4=df.head(4)

# %%
df4
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#              College     Salary college_year
# 0              Texas  7730337.0     2nd Year
# 1          Marquette  6796117.0     2nd Year
# 2  Boston University       None     2nd Year
# 3      Georgia State  1148640.0     1st Year

# %%
m={
    '2nd Year':25,
    '1st Year':22
}
df4.map(m)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [97], line 5
#       1 m={
#       2     '2nd Year':25,
#       3     '1st Year':22
#       4 }
# ----> 5 df4.map(m)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5907, in NDFrame.__getattr__(self, name)
#    5900 if (
#    5901     name not in self._internal_names_set
#    5902     and name not in self._metadata
#    5903     and name not in self._accessors
#    5904     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5905 ):
#    5906     return self[name]
# -> 5907 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'map'

# %%
df5=pd.Series(df4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [98], line 1
# ----> 1 df5=pd.Series(df4)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:387, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     383 else:
#     385     name = ibase.maybe_extract_name(name, data, type(self))
# --> 387     if is_empty_data(data) and dtype is None:
#     388         # gh-17261
#     389         warnings.warn(
#     390             "The default dtype for empty Series will be 'object' instead "
#     391             "of 'float64' in a future version. Specify a dtype explicitly "
#    (...)
#     394             stacklevel=find_stack_level(inspect.currentframe()),
#     395         )
#     396         # uncomment the line below when removing the FutureWarning
#     397         # dtype = np.dtype(object)
#
# ...

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.groupby(['College'])['Team'].describe()
# Out:
#                  count unique                   top freq
# College
# Alabama              3      3   Cleveland Cavaliers    1
# Arizona             13     11   Cleveland Cavaliers    2
# Arizona State        2      2  Los Angeles Clippers    1
# Arkansas             3      3         Chicago Bulls    1
# Baylor               1      1      Sacramento Kings    1
# ...                ...    ...                   ...  ...
# Western Michigan     1      1        Indiana Pacers    1
# Wichita State        1      1       New York Knicks    1
# Wisconsin            5      5          Phoenix Suns    1
# Wyoming              1      1    Los Angeles Lakers    1
# Xavier               1      1     San Antonio Spurs    1
#
# [118 rows x 4 columns]

# %%
df[df.isnull()]
# Out:
#     Name Team  Number Position  Age Height  Weight College  Salary
# 0    NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 1    NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 2    NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 3    NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 4    NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# ..   ...  ...     ...      ...  ...    ...     ...     ...     ...
# 453  NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 454  NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 455  NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 456  NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 457  NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
#
# [458 rows x 9 columns]

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df[df['Salary'].isnull()]
# Out:
#                Name                    Team  Number Position   Age Height  \
# 2      John Holland          Boston Celtics    30.0       SG  27.0    6-5
# 46      Elton Brand      Philadelphia 76ers    42.0       PF  37.0    6-9
# 171   Dahntay Jones     Cleveland Cavaliers    30.0       SG  35.0    6-6
# 264   Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0    6-2
# 269    Ray McCallum       Memphis Grizzlies     5.0       PG  24.0    6-3
# 270  Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 273  Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0   6-10
# 350   Briante Weber              Miami Heat    12.0       PG  23.0    6-2
# 353   Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 397    Axel Toupane          Denver Nuggets     6.0       SG  23.0    6-7
# 409      Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 457             NaN                     NaN     NaN      NaN   NaN    NaN
#
# ...

# %%
df.isnull()
# Out:
#       Name   Team  Number  Position    Age  Height  Weight  College  Salary
# 0    False  False   False     False  False   False   False    False   False
# 1    False  False   False     False  False   False   False    False   False
# 2    False  False   False     False  False   False   False    False    True
# 3    False  False   False     False  False   False   False    False   False
# 4    False  False   False     False  False   False   False     True   False
# ..     ...    ...     ...       ...    ...     ...     ...      ...     ...
# 453  False  False   False     False  False   False   False    False   False
# 454  False  False   False     False  False   False   False     True   False
# 455  False  False   False     False  False   False   False     True   False
# 456  False  False   False     False  False   False   False    False   False
# 457   True   True    True      True   True    True    True     True    True
#
# [458 rows x 9 columns]

# %%
df[df.isnull()]
# Out:
#     Name Team  Number Position  Age Height  Weight College  Salary
# 0    NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 1    NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 2    NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 3    NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 4    NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# ..   ...  ...     ...      ...  ...    ...     ...     ...     ...
# 453  NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 454  NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 455  NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 456  NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 457  NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
#
# [458 rows x 9 columns]

# %%
df6=df.groupby(['College'])['Team']

# %%
for x,y in df6:
    print(x)
    print(y)
    print()
# Out:
# Alabama
# 180     Cleveland Cavaliers
# 266       Memphis Grizzlies
# 287    New Orleans Pelicans
# Name: Team, dtype: object
#
# Arizona
# 18             Brooklyn Nets
# 44           New York Knicks
# 54        Philadelphia 76ers
# 83     Golden State Warriors
# 123             Phoenix Suns
# 167      Cleveland Cavaliers
# 170      Cleveland Cavaliers
# 192          Detroit Pistons
# 201           Indiana Pacers
# 202           Indiana Pacers
# 212          Milwaukee Bucks
# 256          Houston Rockets
# 356            Orlando Magic
# Name: Team, dtype: object
#
# Arizona State
# 92     Los Angeles Clippers
# 249         Houston Rockets
# Name: Team, dtype: object
#
# Arkansas
# 163      Chicago Bulls
# 244    Houston Rockets
# 344         Miami Heat
# Name: Team, dtype: object
#
# Baylor
# 136    Sacramento Kings
# Name: Team, dtype: object
#
# Belmont
# 79    Golden State Warriors
# Name: Team, dtype: object
#
# Blinn College
# 259    Memphis Grizzlies
# ...

# %%
df.groupby(['College'])['Team'].agg(['count'])
# Out:
#                   count
# College
# Alabama               3
# Arizona              13
# Arizona State         2
# Arkansas              3
# Baylor                1
# ...                 ...
# Western Michigan      1
# Wichita State         1
# Wisconsin             5
# Wyoming               1
# Xavier                1
#
# [118 rows x 1 columns]

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
var=df.groupby(['Team'])

# %%
var.get_group('99.0')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [23], line 1
# ----> 1 var.get_group('99.0')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:811, in BaseGroupBy.get_group(self, name, obj)
#     809 inds = self._get_index(name)
#     810 if not len(inds):
# --> 811     raise KeyError(name)
#     813 return obj._take_with_is_copy(inds, axis=self.axis)
#
# KeyError: '99.0'

# %%
for x,y in var:
    print(x)
    print(y)
    print()
# Out:
# Atlanta Hawks
#       Age
# 309  26.0
# 310  24.0
# 311  35.0
# 312  30.0
# 313  31.0
# 314  35.0
# 315  31.0
# 316  24.0
# 317  24.0
# 318  22.0
# 319  27.0
# 320  32.0
# 321  31.0
# 322  24.0
# 323  27.0
#
# Boston Celtics
#      Age
# 0   25.0
# 1   25.0
# 2   27.0
# 3   22.0
# 4   29.0
# 5   29.0
# 6   21.0
# 7   25.0
# 8   22.0
# 9   22.0
# 10  24.0
# 11  27.0
# 12  27.0
# 13  20.0
# 14  26.0
#
# Brooklyn Nets
#      Age
# 15  27.0
# 16  24.0
# 17  28.0
# 18  21.0
# 19  32.0
# 20  22.0
# 21  26.0
# 22  23.0
# 23  28.0
# 24  21.0
# 25  26.0
# 26  25.0
# 27  26.0
# 28  28.0
# 29  27.0
#
# Charlotte Hornets
#       Age
# 324  27.0
# 325  24.0
# 326  27.0
# 327  30.0
# 328  21.0
# 329  28.0
# 330  31.0
# 331  23.0
# 332  22.0
# 333  24.0
# 334  30.0
# 335  27.0
# 336  26.0
# 337  29.0
# 338  23.0
#
# Chicago Bulls
#       Age
# 151  25.0
# 152  31.0
# 153  26.0
# 154  35.0
# 155  23.0
# 156  35.0
# 157  30.0
# 158  27.0
# 159  24.0
# 160  25.0
# 161  27.0
# 162  31.0
# 163  21.0
# ...

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
v1=df.groupby(['Team'])

# %%
for x,y in v1:
    print(x)
    print(y)
    print()
# Out:
# C:\Users\M J\AppData\Local\Temp\ipykernel_10012\1811722786.py:1: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for x,y in v1:
# Atlanta Hawks
#                  Name           Team  Number Position   Age Height  Weight  \
# 309     Kent Bazemore  Atlanta Hawks    24.0       SF  26.0    6-5   201.0
# 310  Tim Hardaway Jr.  Atlanta Hawks    10.0       SG  24.0    6-6   205.0
# 311      Kirk Hinrich  Atlanta Hawks    12.0       SG  35.0    6-4   190.0
# 312        Al Horford  Atlanta Hawks    15.0        C  30.0   6-10   245.0
# 313    Kris Humphries  Atlanta Hawks    43.0       PF  31.0    6-9   235.0
# 314       Kyle Korver  Atlanta Hawks    26.0       SG  35.0    6-7   212.0
# 315      Paul Millsap  Atlanta Hawks     4.0       PF  31.0    6-8   246.0
# ...

# %%
def myfun(text):
    if text=='Boston Celtics':
        return 'N/A'
    else:
        return text

# %%
df['College']=df['Team'].apply(myfun)

# %%
df[df['Team']=='Boston Celtics']
# Out:
#                Name            Team  Number Position   Age Height  Weight  \
# 0     Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1       Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2      John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3       R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4     Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5      Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6     Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7      Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8      Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9      Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 10  Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
# 11    Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9   185.0
# ...
