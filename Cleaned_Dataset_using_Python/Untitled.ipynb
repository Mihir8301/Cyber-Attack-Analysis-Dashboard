# %%
import pandas as pd

# %%
df= pd.read_excel('Output_Cleaned_cyber_attack_dataset02.xlsx')

# %%
df
# Out:
#                    slug event_date  event_year  \
# 0      babb843cbce5db9e 2023-12-31        2023
# 1      581e011d5c37c281 2023-12-31        2023
# 2      fa79c150aac3cf77 2023-12-30        2023
# 3      4d12747a4dd52156 2023-12-30        2023
# 4      1079752e8fe90b4d 2023-12-29        2023
# ...                 ...        ...         ...
# 13402  6100014f6ca84b3d 2014-01-02        2014
# 13403  1f72c2eb8ab303e4 2014-01-01        2014
# 13404  ecac8b3e60a2f72f 2014-01-01        2014
# 13405  3bbe0695e2d019f3 2014-01-01        2014
# 13406  231d0b6dbd7db682 2023-10-29        2023
#
#                                         affected_country  \
# 0      United Kingdom of Great Britain and Northern I...
# 1                                                Belarus
# 2                               United States of America
# 3                             Iran (Islamic Republic of)
# 4                                                 Canada
# ...

# %%
new_order=[ 'AttackDate', 'AttackYear', 'AttackMonth', 'AttackQuarter', 'Country',
       'Spam(%)', 'Ransomware(%)', 'Local Infection(%)', 'Exploit(%)',
       'Malicious Mail(%)', 'Network Attack(%)', 'On Demand Scan(%)',
       'Web Threat(%)']

df=df[new_order]

# %%
df.isnull().sum()
# Out:
# AttackDate            0
# AttackYear            0
# AttackMonth           0
# AttackQuarter         0
# Country               0
# Spam(%)               0
# Ransomware(%)         0
# Local Infection(%)    0
# Exploit(%)            0
# Malicious Mail(%)     0
# Network Attack(%)     0
# On Demand Scan(%)     0
# Web Threat(%)         0
# dtype: int64

# %%
df.to_csv('Extracted_data_cyber_attack_dataset01.csv', index=False)

# %%
df.columns
# Out:
# Index(['AttackDate', 'AttackYear', 'AttackMonth', 'AttackQuarter', 'Country',
#        'Spam(%)', 'Ransomware(%)', 'Local Infection(%)', 'Exploit(%)',
#        'Malicious Mail(%)', 'Network Attack(%)', 'On Demand Scan(%)',
#        'Web Threat(%)', 'Rank Spam', 'Rank Ransomware', 'Rank Local Infection',
#        'Rank Exploit', 'Rank Malicious Mail', 'Rank Network Attack',
#        'Rank On Demand Scan', 'Rank Web Threat'],
#       dtype='object')

# %%
df.dtypes
# Out:
# event_date                 datetime64[ns]
# event_year                          int64
# affected_country                   object
# affected_organization              object
# affected_industry                  object
# afftected_industry_code             int64
# event_type                         object
# event_subtype                      object
# motive                             object
# actor_type                         object
# actor_country                      object
# dtype: object

# %%
new_order=[ 'event_date', 'event_year', 'affected_country', 'affected_organization', 'affected_industry', 'afftected_industry_code', 'event_type', 'event_subtype', 'motive', 'actor', 'actor_type', 'actor_country']

df=df[new_order]

# %%
df
# Out:
#       event_date  event_year  \
# 0     2023-12-31        2023
# 1     2023-12-31        2023
# 2     2023-12-30        2023
# 3     2023-12-30        2023
# 4     2023-12-29        2023
# ...          ...         ...
# 13402 2014-01-02        2014
# 13403 2014-01-01        2014
# 13404 2014-01-01        2014
# 13405 2014-01-01        2014
# 13406 2023-10-29        2023
#
#                                         affected_country  \
# 0      United Kingdom of Great Britain and Northern I...
# 1                                                Belarus
# 2                               United States of America
# 3                             Iran (Islamic Republic of)
# 4                                                 Canada
# ...                                                  ...
# 13402                           United States of America
# 13403                           United States of America
# 13404                           United States of America
# ...

# %%
df.to_excel('Extracted_data_cyber_attack_dataset02.xlsx', index=False)
